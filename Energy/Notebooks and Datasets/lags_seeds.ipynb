# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from sklearn import linear_model

# %%
price = pd.read_csv('PWHEAMTUSDM.csv') # WHEAT
seeds_0 = pd.read_csv('seeds.csv') # seeds

test = pd.merge(price, seeds_0)

lags = range(1, 13)  # Just two lags for demonstration.

lagged_df = test.assign(**{f'seed_price (t-{lag})': test['WPU02550304'].shift(lag) for lag in lags})
lagged_df = lagged_df.rename(columns={"WPU02550304": "seed_price (t)", "PWHEAMTUSDM": "wheat_price"})
lagged_df
# Out:
#            DATE  wheat_price  seed_price (t)  seed_price (t-1)  \
# 0    1991-06-01   120.151794         100.000               NaN
# 1    1991-07-01   118.209587         102.400           100.000
# 2    1991-08-01   125.326843         102.400           102.400
# 3    1991-09-01   135.372879         102.400           102.400
# 4    1991-10-01   146.887192         101.700           102.400
# ..          ...          ...             ...               ...
# 388  2023-10-01   216.463939         187.977           186.956
# 389  2023-11-01   216.000269         186.640           187.977
# 390  2023-12-01   229.633413         187.556           186.640
# 391  2024-01-01   226.078532         187.396           187.556
# 392  2024-02-01   219.238068         187.544           187.396
#
#      seed_price (t-2)  seed_price (t-3)  seed_price (t-4)  seed_price (t-5)  \
# 0                 NaN               NaN               NaN               NaN
# 1                 NaN               NaN               NaN               NaN
# 2             100.000               NaN               NaN               NaN
# 3             102.400           100.000               NaN               NaN
# 4             102.400           102.400           100.000               NaN
# ..                ...               ...               ...               ...
# 388           192.363           196.723           191.209           190.408
# 389           186.956           192.363           196.723           191.209
# 390           187.977           186.956           192.363           196.723
# 391           186.640           187.977           186.956           192.363
# 392           187.556           186.640           187.977           186.956
#
#      seed_price (t-6)  seed_price (t-7)  seed_price (t-8)  seed_price (t-9)  \
# 0                 NaN               NaN               NaN               NaN
# 1                 NaN               NaN               NaN               NaN
# 2                 NaN               NaN               NaN               NaN
# 3                 NaN               NaN               NaN               NaN
# 4                 NaN               NaN               NaN               NaN
# ..                ...               ...               ...               ...
# 388           187.897           186.425           186.789           187.859
# 389           190.408           187.897           186.425           186.789
# 390           191.209           190.408           187.897           186.425
# 391           196.723           191.209           190.408           187.897
# 392           192.363           196.723           191.209           190.408
#
#      seed_price (t-10)  seed_price (t-11)  seed_price (t-12)
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ..                 ...                ...                ...
# 388            192.877            195.067            196.325
# 389            187.859            192.877            195.067
# 390            186.789            187.859            192.877
# 391            186.425            186.789            187.859
# 392            187.897            186.425            186.789
#
# [393 rows x 15 columns]

# %%
y_lag = lagged_df.wheat_price # target
col_names = lagged_df.columns.values.tolist()
col_names.remove('DATE')
col_names.remove('wheat_price')
X_lag = lagged_df[col_names]

# %%
#run correlations
#for each in col_names, run a correlation with wheat prices
corr_lag = {}
for i, e in enumerate(X_lag):
    corr_lag['t+'+ str(i)] = lagged_df["wheat_price"].corr(lagged_df[e])
    print(f"When lagged by {i} months, the correlation between wheat prices and seed prices is {corr_lag['t+'+str(i)]}.")
# Out:
# When lagged by 0 months, the correlation between wheat prices and seed prices is 0.46427014826258917.
# When lagged by 1 months, the correlation between wheat prices and seed prices is 0.4590705692868967.
# When lagged by 2 months, the correlation between wheat prices and seed prices is 0.45524558479843047.
# When lagged by 3 months, the correlation between wheat prices and seed prices is 0.4506731615216862.
# When lagged by 4 months, the correlation between wheat prices and seed prices is 0.44702554677932976.
# When lagged by 5 months, the correlation between wheat prices and seed prices is 0.4426749641519311.
# When lagged by 6 months, the correlation between wheat prices and seed prices is 0.43937417091810266.
# When lagged by 7 months, the correlation between wheat prices and seed prices is 0.436096460255932.
# When lagged by 8 months, the correlation between wheat prices and seed prices is 0.43171112698931335.
# When lagged by 9 months, the correlation between wheat prices and seed prices is 0.4266932655830614.
# When lagged by 10 months, the correlation between wheat prices and seed prices is 0.42068542777931944.
# When lagged by 11 months, the correlation between wheat prices and seed prices is 0.41468225767167266.
# When lagged by 12 months, the correlation between wheat prices and seed prices is 0.4096958306794268.
