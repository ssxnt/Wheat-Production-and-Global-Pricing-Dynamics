# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('PCU325311325311.csv')

# %%
df.head()
# Out:
#          DATE PCU325311325311
# 0  1975-12-01            88.1
# 1  1976-01-01            87.6
# 2  1976-02-01            85.0
# 3  1976-03-01            84.8
# 4  1976-04-01            84.7

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df = df.loc[df['PCU325311325311'] != '.']

# %%
df['PCU325311325311'] = df['PCU325311325311'].map(float)

# %%
fig, ax1 = plt.subplots()
df.plot(x='DATE', y='PCU325311325311', ax=ax1)
# Out:
# <Axes: xlabel='DATE'>
